# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %% [markdown]
# # Load Datasetm

# %%
data_path = "../data/jutsu.jsonl"
df = pd.read_json(data_path, lines=True)
df.head()
# Out:
#                 jutsu_name                        jutsu_type  \
# 0               Asura Path  Kekkei Genkai, Ninjutsu, Dōjutsu
# 1             10 Hit Combo                          Taijutsu
# 2  Assassination Technique          Kenjutsu, Fighting Style
# 3              Art (jutsu)    Kekkei Genkai, Hiden, Ninjutsu
# 4             Asura Attack  Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description
# 0  This article is about information on the abili...
# 1  Lars strikes the foe 5 times before striking t...
# 2  A sword technique used by Root members. Using ...
# 3  This article is about the jutsu from Naruto Sh...
# 4  With the body modifications of the Asura Path,...

# %%
def simplify_jutsu(jutsu):
    if "Genjutsu" in jutsu:
        return "Genjutsu"
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    if "Taijutsu" in jutsu:
        return "Taijutsu"

# %%
df['jutsu_type_simplified'] = df['jutsu_type'].apply(simplify_jutsu)

# %%
df.head()
# Out:
#                 jutsu_name                        jutsu_type  \
# 0               Asura Path  Kekkei Genkai, Ninjutsu, Dōjutsu
# 1             10 Hit Combo                          Taijutsu
# 2  Assassination Technique          Kenjutsu, Fighting Style
# 3              Art (jutsu)    Kekkei Genkai, Hiden, Ninjutsu
# 4             Asura Attack  Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description jutsu_type_simplified
# 0  This article is about information on the abili...              Ninjutsu
# 1  Lars strikes the foe 5 times before striking t...              Taijutsu
# 2  A sword technique used by Root members. Using ...                  None
# 3  This article is about the jutsu from Naruto Sh...              Ninjutsu
# 4  With the body modifications of the Asura Path,...              Ninjutsu

# %%
df['jutsu_type_simplified'].value_counts()
# Out:
# jutsu_type_simplified
# Ninjutsu    2272
# Taijutsu     398
# Genjutsu     101
# Name: count, dtype: int64

# %%
df['text'] = df['jutsu_name'] + ". " + df['jutsu_description']
df['jutsus'] = df['jutsu_type_simplified']
df = df[['text', 'jutsus']]
df = df.dropna()

# %%
df.head()
# Out:
#                                                 text    jutsus
# 0  Asura Path. This article is about information ...  Ninjutsu
# 1  10 Hit Combo. Lars strikes the foe 5 times bef...  Taijutsu
# 3  Art (jutsu). This article is about the jutsu f...  Ninjutsu
# 4  Asura Attack. With the body modifications of t...  Ninjutsu
# 5  Ascension and Fall. Obito slashes the opponent...  Ninjutsu

# %%
from bs4 import BeautifulSoup

class Cleaner():
    def __init__(self):
        pass
    
    def put_line_breaks(self, text):
        return text.replace("<\p>", "<\p>\n")

    def remove_html_tags(self, text):
        clean_text = BeautifulSoup(text, "lxml").text
        return clean_text

    def clean(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tags(text)
        text = text.strip()
        return text
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\PREM\AppData\Local\Temp\ipykernel_12964\1949126359.py:8: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")
# C:\Users\PREM\AppData\Local\Temp\ipykernel_12964\1949126359.py:8: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")

# %%
text_column_name = 'text'
label_column_name = 'jutsus'

# %%
# Clean the text
cleaner = Cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean)

# %%
df.head(2)
# Out:
#                                                 text    jutsus  \
# 0  Asura Path. This article is about information ...  Ninjutsu
# 1  10 Hit Combo. Lars strikes the foe 5 times bef...  Taijutsu
#
#                                         text_cleaned
# 0  Asura Path. This article is about information ...
# 1  10 Hit Combo. Lars strikes the foe 5 times bef...

# %%
# Encode the labels
le = preprocessing.LabelEncoder()
le.fit(df[label_column_name].tolist())
# Out:
# LabelEncoder()

# %%
label_dict = {index:label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_column_name].tolist())

# %%
df.head()
# Out:
#                                                 text    jutsus  \
# 0  Asura Path. This article is about information ...  Ninjutsu
# 1  10 Hit Combo. Lars strikes the foe 5 times bef...  Taijutsu
# 3  Art (jutsu). This article is about the jutsu f...  Ninjutsu
# 4  Asura Attack. With the body modifications of t...  Ninjutsu
# 5  Ascension and Fall. Obito slashes the opponent...  Ninjutsu
#
#                                         text_cleaned  label
# 0  Asura Path. This article is about information ...      1
# 1  10 Hit Combo. Lars strikes the foe 5 times bef...      2
# 3  Art (jutsu). This article is about the jutsu f...      1
# 4  Asura Attack. With the body modifications of t...      1
# 5  Ascension and Fall. Obito slashes the opponent...      1

# %%
test_size = 0.2
df_train, df_test = train_test_split(df, test_size=test_size, stratify=df['label'],)

# %%
df_train['jutsus'].value_counts()
# Out:
# jutsus
# Ninjutsu    1817
# Taijutsu     318
# Genjutsu      81
# Name: count, dtype: int64

# %%
model_name = "distilbert/distilbert-base-uncased"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess_function(tokenizer, examples):
    return tokenizer(examples['text_cleaned'], truncation=True)

# %%
# Convert Pandas to Hugging Face Dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

# Tokenize the dataset
tokenize_train = train_dataset.map(lambda examples: preprocess_function(tokenizer, examples),batched=True)
tokenize_test = test_dataset.map(lambda examples: preprocess_function(tokenizer, examples),batched=True)
# Out:
# Map: 100%|██████████| 2216/2216 [00:00<00:00, 5048.22 examples/s]
# Map: 100%|██████████| 555/555 [00:00<00:00, 6488.62 examples/s]
